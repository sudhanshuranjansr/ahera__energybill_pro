# %%
from pandas import Series,DataFrame
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style("whitegrid")
import statistics

# %%
df1=pd.read_csv("train.csv")
df2=pd.read_csv("weather_train.csv")
df3=pd.read_csv("building_metadata.csv")

# %% [raw]
# df1=df1[0:1000]
# df2=df2[0:1000]
# df3=df3[0:1000]

# %%
df1.head(21)
# Out:
#     building_id  meter            timestamp  meter_reading
# 0             0      0  2016-01-01 00:00:00            0.0
# 1             1      0  2016-01-01 00:00:00            0.0
# 2             2      0  2016-01-01 00:00:00            0.0
# 3             3      0  2016-01-01 00:00:00            0.0
# 4             4      0  2016-01-01 00:00:00            0.0
# 5             5      0  2016-01-01 00:00:00            0.0
# 6             6      0  2016-01-01 00:00:00            0.0
# 7             7      0  2016-01-01 00:00:00            0.0
# 8             8      0  2016-01-01 00:00:00            0.0
# 9             9      0  2016-01-01 00:00:00            0.0
# 10           10      0  2016-01-01 00:00:00            0.0
# 11           11      0  2016-01-01 00:00:00            0.0
# 12           12      0  2016-01-01 00:00:00            0.0
# 13           13      0  2016-01-01 00:00:00            0.0
# 14           14      0  2016-01-01 00:00:00            0.0
# ...

# %%
#meter in df1 is actually the meter type

# %%
len(df1["building_id"].values)/len(np.unique(df1["building_id"].values))
# Out:
# 13951.75983436853

# %%
#every building id has approx repetation as abobe frequency(13951.75983436853)

# %%
df2.head(2)
# Out:
#    site_id            timestamp  air_temperature  cloud_coverage  \
# 0        0  2016-01-01 00:00:00             25.0             6.0
# 1        0  2016-01-01 01:00:00             24.4             NaN
#
#    dew_temperature  precip_depth_1_hr  sea_level_pressure  wind_direction  \
# 0             20.0                NaN              1019.7             0.0
# 1             21.1               -1.0              1020.2            70.0
#
#    wind_speed
# 0         0.0
# 1         1.5

# %%
#df2 is actually giving the weather condition of every location for each year hourwise

# %%
len(np.unique(df3["building_id"].values))==len(np.unique(df1["building_id"].values))
# Out:
# True

# %%
len(np.unique(df3["building_id"].values))==len((df3["building_id"].values))
# Out:
# True

# %% [markdown]
# so this true value cleraly indicates that df3 is actually a dictionary which is giving the discription of the building for each building for a particular site

# %%
df3.head(2)
# Out:
#    site_id  building_id primary_use  square_feet  year_built  floor_count
# 0        0            0   Education         7432      2008.0          NaN
# 1        0            1   Education         2720      2004.0          NaN

# %%
len(df1["building_id"].unique())          #so we have the inforamtion about 1500 diffferent buildings
# Out:
# 784

# %% [markdown]
# # Data_preprocessing

# %% [markdown]
# #we need to mix the three data sets here as the data set one reales with the dataset 3 by the common key "buliding_id",and the 3rd dataset belongs the 2nd data with another common key that is site_id

# %% [markdown]
# so what so ever be the time  or site the specifiations of a building is not going to change
# so we can think of merging df1 to df3 on "building_id"

# %%
df3.head(2)
# Out:
#    site_id  building_id primary_use  square_feet  year_built  floor_count
# 0        0            0   Education         7432      2008.0          NaN
# 1        0            1   Education         2720      2004.0          NaN

# %%
df1.head(3)
# Out:
#    building_id  meter            timestamp  meter_reading
# 0            0      0  2016-01-01 00:00:00            0.0
# 1            1      0  2016-01-01 00:00:00            0.0
# 2            2      0  2016-01-01 00:00:00            0.0

# %%
l1=int(len(df1["building_id"]))
b1=int(len(df3.columns))
a=np.repeat(0,len(df1["building_id"])*len(df3.columns))

# %%
b=a.reshape(l1,b1)
dfb=DataFrame(b,columns=df3.columns)

# %%
(dfb).merge(df1)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-80-095534b5bfef> in <module>
# ----> 1 (dfb).merge(df1)
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    6387                      right_on=right_on, left_index=left_index,
#    6388                      right_index=right_index, sort=sort, suffixes=suffixes,
# -> 6389                      copy=copy, indicator=indicator, validate=validate)
#    6390
#    6391     def round(self, decimals=0, *args, **kwargs):
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
# ...

# %%
def com(c,df21):
    s=[]
    for i in np.arange(len(df21["building_id"])):
        if (df21["building_id"][i])==c:
            s=np.append(s,i)
    return(s)

# %%
com(df3["building_id"][0],df1)
# Out:
# array([0.0000000e+00, 2.3010000e+03, 4.5940000e+03, ..., 2.0209003e+07,
#        2.0211368e+07, 2.0213734e+07])

# %%
def filler(s_df,df12):
    col=s_df.columns
    for i in np.arange(len(df12["building_id"])):
        for j in col:
            df12[j][i]=s_df[j][i]

# %%
df1
# Out:
#           building_id  meter            timestamp  meter_reading
# 0                   0      0  2016-01-01 00:00:00         0.0000
# 1                   1      0  2016-01-01 00:00:00         0.0000
# 2                   2      0  2016-01-01 00:00:00         0.0000
# 3                   3      0  2016-01-01 00:00:00         0.0000
# 4                   4      0  2016-01-01 00:00:00         0.0000
# 5                   5      0  2016-01-01 00:00:00         0.0000
# 6                   6      0  2016-01-01 00:00:00         0.0000
# 7                   7      0  2016-01-01 00:00:00         0.0000
# 8                   8      0  2016-01-01 00:00:00         0.0000
# 9                   9      0  2016-01-01 00:00:00         0.0000
# 10                 10      0  2016-01-01 00:00:00         0.0000
# 11                 11      0  2016-01-01 00:00:00         0.0000
# 12                 12      0  2016-01-01 00:00:00         0.0000
# ...

# %%
df3=df3.drop("floor_count",axis=1)

# %%
df13=pd.merge(df1,df3,on="building_id")

# %%
df13.tail()
# Out:
#      building_id  meter            timestamp  meter_reading  site_id  \
# 995          802      0  2016-01-01 00:00:00           0.00        7
# 996          802      1  2016-01-01 00:00:00         362.98        7
# 997          802      2  2016-01-01 00:00:00        1491.22        7
# 998          803      0  2016-01-01 00:00:00        4791.84        7
# 999          803      1  2016-01-01 00:00:00           0.00        7
#
#     primary_use  square_feet  year_built
# 995   Education       290625      1995.0
# 996   Education       290625      1995.0
# 997   Education       290625      1995.0
# 998   Education       182986      1962.0
# 999   Education       182986      1962.0

# %%
df2.tail()
# Out:
#      site_id            timestamp  air_temperature  cloud_coverage  \
# 995        0  2016-02-11 11:00:00              4.4             0.0
# 996        0  2016-02-11 12:00:00              3.3             2.0
# 997        0  2016-02-11 13:00:00              6.1             0.0
# 998        0  2016-02-11 14:00:00              9.4             0.0
# 999        0  2016-02-11 15:00:00             12.2             0.0
#
#      dew_temperature  precip_depth_1_hr  sea_level_pressure  wind_direction  \
# 995              1.1                0.0              1026.1             NaN
# 996              0.6                0.0              1026.9             0.0
# 997              0.6                0.0              1027.2           360.0
# 998             -1.1                0.0              1027.5           350.0
# 999             -4.4                0.0              1027.7           350.0
#
#      wind_speed
# 995         1.5
# 996         0.0
# 997         2.6
# 998         4.6
# 999         5.1

# %%
char=df13["timestamp"][0]
char
# Out:
# '2016-01-01 00:00:00'

# %%
for i in (df2["timestamp"]):
    if i==char:
        print(i)
# Out:
# 2016-01-01 00:00:00

# %%
df13=df13.drop("floor_count",axis=1)

# %%
df=pd.merge(df13,df2)

# %%
df2.head(1)
# Out:
#    site_id            timestamp  air_temperature  cloud_coverage  \
# 1        0  2016-01-01 01:00:00             24.4             NaN
#
#    dew_temperature  precip_depth_1_hr  sea_level_pressure  wind_direction  \
# 1             21.1               -1.0              1020.2            70.0
#
#    wind_speed
# 1         1.5

# %%
df13.head(1)
# Out:
#    building_id  meter            timestamp  meter_reading  site_id  \
# 0            1      0  2016-01-01 00:00:00            0.0        0
#
#   primary_use  square_feet  year_built
# 0   Education         2720      2004.0

# %%
#df.csv("energy_df.csv")

# %%
#df_test=pd.read_csv("test.csv")

# %%
#df=df[1:500]

# %%
df.head(1)
# Out:
#    building_id  meter            timestamp  meter_reading  site_id  \
# 0            0      0  2016-01-01 00:00:00            0.0        0
#
#   primary_use  square_feet  year_built  floor_count  air_temperature  \
# 0   Education         7432      2008.0          NaN             25.0
#
#    cloud_coverage  dew_temperature  precip_depth_1_hr  sea_level_pressure  \
# 0             6.0             20.0                NaN              1019.7
#
#    wind_direction  wind_speed
# 0             0.0         0.0

# %%
df11=df.drop("floor_count",axis=1)

# %%
df
# Out:
#      building_id  meter            timestamp  meter_reading  site_id  \
# 1              1      0  2016-01-01 00:00:00            0.0        0
# 2              2      0  2016-01-01 00:00:00            0.0        0
# 3              3      0  2016-01-01 00:00:00            0.0        0
# 4              4      0  2016-01-01 00:00:00            0.0        0
# 5              5      0  2016-01-01 00:00:00            0.0        0
# 6              6      0  2016-01-01 00:00:00            0.0        0
# 7              7      0  2016-01-01 00:00:00            0.0        0
# 8              8      0  2016-01-01 00:00:00            0.0        0
# 9              9      0  2016-01-01 00:00:00            0.0        0
# 10            10      0  2016-01-01 00:00:00            0.0        0
# 11            11      0  2016-01-01 00:00:00            0.0        0
# 12            12      0  2016-01-01 00:00:00            0.0        0
# 13            13      0  2016-01-01 00:00:00            0.0        0
# ...
